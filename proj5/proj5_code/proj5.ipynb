# %% [markdown]
# ## Proj5
# 本项目通过程序仿真的方式实现了光束在自由空间中衍射的过程，衍射过程可以通过衍射光学元件 (Diffractive Optical Elements, DOE)人为调控，DOE通常采用微纳刻蚀工艺构成二维分布的衍射单元，每个衍射单元可以有特定的形貌、折射率等，对激光波前位相分布进行精细调控。激光经过每个衍射单元后发生衍射，并在一定距离（通常为无穷远或透镜焦平面）处产生干涉，形成特定的光强分布。
#
# 本项目基于光学神经网络实现了在手写数字识别数据集(MNIST)上的图像分类功能。你需要完成student_code.py中的commplex_exp_torch、ifftshift2d_tf、transp_ifft2d、transp_fft2d四个函数，感受通过梯度下降的方式优化硬件参数设计的过程。

# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader
import os
from tqdm.notebook import tqdm
from student_code import *

#####################################################
# 固定参数，不需要调整
padamt = 80
otf_size = 142
classes = 10

#####################################################
train_batch_size = 128
test_batch_size = 64  

learning_rate = 0.00001 

#####################################################
train_dataset = MyDataset(train=True)
test_dataset = MyDataset(train=False)

train_loader = DataLoader(dataset=train_dataset, batch_size=train_batch_size, shuffle=True, pin_memory=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=test_batch_size, shuffle=False, pin_memory=True)

# %%
#调用GPU
# os.environ["CUDA_VISIBLE_DEVICES"]="1"
device = torch.device("cuda")
torch.cuda.empty_cache()        #释放显存

model = onn()
model.to(device)

#####################################################
# 构建损失函数
criterion = torch.nn.CrossEntropyLoss()      #交叉熵
# 构建优化器
optimizer = optim.SGD(model.parameters(),lr=learning_rate,momentum=0.5)    #带动量0.5
# 设置学习率梯度下降，如果连续2个epoch测试准确率没有上升，则降低学习率，系数0.5
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2, verbose=True, threshold=0.00005, threshold_mode='rel', cooldown=0, min_lr=1e-7, eps=1e-08)

#####################################################
train_epoch = []
model_accuracy = []
temp_acc = 0.0
train_loss_val = []
max_acc = 0
# Out:
# /mnt/hdd2/wushihan/miniconda3/envs/new/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
def train(epoch):
    running_loss =0.0
    for batch_idx,data in enumerate(train_loader,0):
        inputs,target = data
        inputs,target = inputs.to(device),target.to(device)
        optimizer.zero_grad()

        #forward,backward,update
        outputs = model(inputs)
        outputs = img_split(outputs)

        loss = criterion(outputs,target)
        loss.backward()
        optimizer.step()

        running_loss+=loss.item()

    tqdm.write('loss: %.3f' % (loss.item()))
    return running_loss

# %%
def test():
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            outputs = img_split(outputs)
            
            _, predicted = torch.max(outputs.data,dim=1)       #从第一维度开始搜索
            _, labels = torch.max(labels, dim=1)
            total += labels.size(0)
            correct += (predicted==labels).sum().item()
    tqdm.write('Accuracy on test set: %f %% [%d/%d]' % (100 * correct / total, correct, total))

    return correct/total

# %%
losses, acces = [], []
for epoch in tqdm(range(30)):
    tqdm.write('Epoch: %d' % (epoch + 1))
    losses.append(train(epoch))
    acc = test()
    acces.append(acc)

    if acc > max_acc:
        max_acc = acc
    train_epoch.append(epoch)
    model_accuracy.append(acc)
    scheduler.step(acc)
print('acc:', max_acc)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1
# loss: 0.485
# Accuracy on test set: 81.750000 % [8175/10000]
# Epoch: 2
# loss: 0.409
# Accuracy on test set: 88.420000 % [8842/10000]
# Epoch: 3
# loss: 0.346
# Accuracy on test set: 89.700000 % [8970/10000]
# Epoch: 4
# loss: 0.459
# Accuracy on test set: 91.560000 % [9156/10000]
# Epoch: 5
# loss: 0.404
# Accuracy on test set: 91.080000 % [9108/10000]
# Epoch: 6
# loss: 0.558
# Accuracy on test set: 85.870000 % [8587/10000]
# Epoch: 7
# loss: 0.295
# Accuracy on test set: 89.630000 % [8963/10000]
# Epoch: 8
# loss: 0.258
# Accuracy on test set: 93.210000 % [9321/10000]
# Epoch: 9
# loss: 0.275
# Accuracy on test set: 94.010000 % [9401/10000]
# Epoch: 10
# loss: 0.279
# Accuracy on test set: 92.780000 % [9278/10000]
# Epoch: 11
# loss: 0.404
# Accuracy on test set: 93.330000 % [9333/10000]
# Epoch: 12
# loss: 0.364
# Accuracy on test set: 93.860000 % [9386/10000]
# Epoch: 13
# loss: 0.239
# Accuracy on test set: 95.020000 % [9502/10000]
# Epoch: 14
# loss: 0.375
# Accuracy on test set: 94.460000 % [9446/10000]
# Epoch: 15
# loss: 0.352
# Accuracy on test set: 94.790000 % [9479/10000]
# Epoch: 16
# loss: 0.231
# Accuracy on test set: 94.750000 % [9475/10000]
# Epoch: 17
# loss: 0.195
# Accuracy on test set: 94.950000 % [9495/10000]
# Epoch: 18
# loss: 0.227
# Accuracy on test set: 94.590000 % [9459/10000]
# Epoch: 19
# loss: 0.308
# Accuracy on test set: 95.060000 % [9506/10000]
# Epoch: 20
# loss: 0.277
# Accuracy on test set: 95.190000 % [9519/10000]
# Epoch: 21
# loss: 0.285
# Accuracy on test set: 95.160000 % [9516/10000]
# Epoch: 22
# loss: 0.235
# Accuracy on test set: 94.690000 % [9469/10000]
# Epoch: 23
# loss: 0.290
# Accuracy on test set: 94.930000 % [9493/10000]
# Epoch: 24
# loss: 0.304
# Accuracy on test set: 95.130000 % [9513/10000]
# Epoch: 25
# loss: 0.351
# Accuracy on test set: 95.390000 % [9539/10000]
# Epoch: 26
# loss: 0.267
# Accuracy on test set: 95.230000 % [9523/10000]
# Epoch: 27
# loss: 0.249
# Accuracy on test set: 95.210000 % [9521/10000]
# Epoch: 28
# loss: 0.201
# Accuracy on test set: 95.180000 % [9518/10000]
# Epoch: 29
# loss: 0.233
# Accuracy on test set: 95.280000 % [9528/10000]
# Epoch: 30
# loss: 0.265
# Accuracy on test set: 95.330000 % [9533/10000]
# acc: 0.9539

# %%
import matplotlib.pyplot as plt

# draw subplot loss and acc
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(30), losses, label='train_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(30), acces, label='test_acc')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()

plt.show()

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)  # 随机获取部分数据
image = images[0:2].to(device)

# 现在你可以将图片送入模型
output = model(image)

print(output.shape)
print(img_split(output))

plt.subplot(1,2,1)
plt.imshow(image[0].reshape(32,32).cpu().numpy(), cmap='gray')
plt.subplot(1,2,2)
plt.imshow(output[0].squeeze().cpu().detach().numpy(), cmap='gray')
plt.show()
# Out:
# torch.Size([2, 192, 192, 1])
# torch.Size([2, 10])
# tensor([[ 8.8166,  7.5194,  9.1813,  9.5894, 11.4546,  7.7350,  8.4401, 11.7821,
#          10.9651, 15.3894],
#         [ 9.6049,  8.9114,  8.1221,  9.4134, 11.0516,  9.6865,  8.4591, 12.0089,
#          11.3035, 14.1994]], device='cuda:0', grad_fn=<TransposeBackward0>)
